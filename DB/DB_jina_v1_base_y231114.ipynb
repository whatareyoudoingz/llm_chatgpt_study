# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# cd /content/drive/MyDrive/intern/llm_chatgpt_study/DB
# Out:
# /content/drive/MyDrive/intern/llm_chatgpt_study/DB

# %%
# !git clone https://github.com/eosphoros-ai/DB-GPT.git
# Out:
# Cloning into 'DB-GPT'...
# remote: Enumerating objects: 26629, done.
# remote: Counting objects: 100% (26629/26629), done.
# remote: Compressing objects: 100% (8378/8378), done.
# remote: Total 26629 (delta 17366), reused 26428 (delta 17275), pack-reused 0
# Receiving objects: 100% (26629/26629), 162.44 MiB | 14.35 MiB/s, done.
# Resolving deltas: 100% (17366/17366), done.
# Updating files: 100% (714/714), done.

# %%
cd ./DB-GPT
# Out:
# /content/drive/MyDrive/intern/llm_chatgpt_study/DB/DB-GPT

# %%
# !pip install -e ".[default]"
# Out:
# Obtaining file:///content/drive/MyDrive/intern/llm_chatgpt_study/DB/DB-GPT
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: aiohttp==3.8.4 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (3.8.4)
# Requirement already satisfied: chardet==5.1.0 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (5.1.0)
# Requirement already satisfied: importlib-resources==5.12.0 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (5.12.0)
# Requirement already satisfied: psutil==5.9.4 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (5.9.4)
# Requirement already satisfied: python-dotenv==1.0.0 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (1.0.0)
# Requirement already satisfied: colorama==0.4.6 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.4.6)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (3.9.0)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (5.3.2)
# Requirement already satisfied: tokenizers==0.13.3 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.13.3)
# Requirement already satisfied: accelerate>=0.20.3 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.24.1)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (2.2.2)
# Requirement already satisfied: protobuf==3.20.3 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (3.20.3)
# Requirement already satisfied: zhipuai in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (1.0.7)
# Requirement already satisfied: dashscope in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (1.13.2)
# Requirement already satisfied: GitPython in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (3.1.40)
# Requirement already satisfied: fschat in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.2.32)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (15.0.1)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.25.1)
# Requirement already satisfied: sqlparse==0.4.4 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.4.4)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.12.2)
# Requirement already satisfied: pandas==2.0.3 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (2.0.3)
# Requirement already satisfied: auto-gpt-plugin-template in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.0.3)
# Requirement already satisfied: gTTS==2.3.1 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (2.3.1)
# Requirement already satisfied: langchain>=0.0.286 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.0.335)
# Requirement already satisfied: SQLAlchemy==2.0.22 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (2.0.22)
# Requirement already satisfied: fastapi==0.98.0 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.98.0)
# Requirement already satisfied: pymysql in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (1.1.0)
# Requirement already satisfied: duckdb==0.8.1 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.8.1)
# Requirement already satisfied: duckdb-engine in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.9.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (4.19.2)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (4.33.3)
# Requirement already satisfied: alembic==1.12.0 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (1.12.0)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (3.1.2)
# Requirement already satisfied: spacy==3.5.3 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (3.5.3)
# Requirement already satisfied: chromadb==0.4.10 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.4.10)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (3.5.1)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.0.1)
# Requirement already satisfied: python-pptx in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.6.23)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (1.1.0)
# Requirement already satisfied: pypdf in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (3.17.0)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.0.6)
# Requirement already satisfied: torch==2.0.1 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (2.0.1)
# Requirement already satisfied: torchvision==0.15.2 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.15.2)
# Requirement already satisfied: torchaudio==2.0.2 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (2.0.2)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.41.2.post2)
# Requirement already satisfied: cpm_kernels in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (1.0.11)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.4->db-gpt==0.4.1) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.4->db-gpt==0.4.1) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.4->db-gpt==0.4.1) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.4->db-gpt==0.4.1) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.4->db-gpt==0.4.1) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.4->db-gpt==0.4.1) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.4->db-gpt==0.4.1) (1.3.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic==1.12.0->db-gpt==0.4.1) (1.3.0)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic==1.12.0->db-gpt==0.4.1) (4.5.0)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (2.31.0)
# Requirement already satisfied: pydantic<2.0,>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (1.10.13)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (0.7.3)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (0.24.0.post1)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (3.0.2)
# Requirement already satisfied: pulsar-client>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (3.3.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (1.16.2)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (7.4.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (4.0.1)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (1.23.5)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.98.0->db-gpt==0.4.1) (0.27.0)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gTTS==2.3.1->db-gpt==0.4.1) (8.1.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3->db-gpt==0.4.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3->db-gpt==0.4.1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3->db-gpt==0.4.1) (2023.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (2.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (6.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (3.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy==2.0.22->db-gpt==0.4.1) (3.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->db-gpt==0.4.1) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->db-gpt==0.4.1) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->db-gpt==0.4.1) (3.2.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->db-gpt==0.4.1) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->db-gpt==0.4.1) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->db-gpt==0.4.1) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->db-gpt==0.4.1) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->db-gpt==0.4.1) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->db-gpt==0.4.1) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->db-gpt==0.4.1) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->db-gpt==0.4.1) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->db-gpt==0.4.1) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->db-gpt==0.4.1) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->db-gpt==0.4.1) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->db-gpt==0.4.1) (2.0.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.15.2->db-gpt==0.4.1) (9.4.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->db-gpt==0.4.1) (0.41.3)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->db-gpt==0.4.1) (3.27.7)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->db-gpt==0.4.1) (17.0.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->db-gpt==0.4.1) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.3->db-gpt==0.4.1) (0.19.1)
# Requirement already satisfied: anyio<4.0 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.286->db-gpt==0.4.1) (3.7.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.286->db-gpt==0.4.1) (0.6.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.286->db-gpt==0.4.1) (1.33)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.63 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.286->db-gpt==0.4.1) (0.0.64)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.286->db-gpt==0.4.1) (8.2.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->db-gpt==0.4.1) (2023.6.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->db-gpt==0.4.1) (0.4.0)
# Requirement already satisfied: abstract-singleton in /usr/local/lib/python3.10/dist-packages (from auto-gpt-plugin-template->db-gpt==0.4.1) (1.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->db-gpt==0.4.1) (4.11.2)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->db-gpt==0.4.1) (10.0)
# Requirement already satisfied: markdown2[all] in /usr/local/lib/python3.10/dist-packages (from fschat->db-gpt==0.4.1) (2.4.10)
# Requirement already satisfied: nh3 in /usr/local/lib/python3.10/dist-packages (from fschat->db-gpt==0.4.1) (0.2.14)
# Requirement already satisfied: prompt-toolkit>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from fschat->db-gpt==0.4.1) (3.0.39)
# Requirement already satisfied: rich>=10.0.0 in /usr/local/lib/python3.10/dist-packages (from fschat->db-gpt==0.4.1) (13.6.0)
# Requirement already satisfied: shortuuid in /usr/local/lib/python3.10/dist-packages (from fschat->db-gpt==0.4.1) (1.0.11)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (from fschat->db-gpt==0.4.1) (0.5.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from GitPython->db-gpt==0.4.1) (4.0.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->db-gpt==0.4.1) (2023.7.22)
# Requirement already satisfied: httpcore in /usr/local/lib/python3.10/dist-packages (from httpx->db-gpt==0.4.1) (1.0.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->db-gpt==0.4.1) (3.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->db-gpt==0.4.1) (1.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->db-gpt==0.4.1) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->db-gpt==0.4.1) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->db-gpt==0.4.1) (0.12.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->db-gpt==0.4.1) (1.1.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->db-gpt==0.4.1) (0.2.9)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx->db-gpt==0.4.1) (4.9.3)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from python-pptx->db-gpt==0.4.1) (3.1.9)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn->db-gpt==0.4.1) (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->db-gpt==0.4.1) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->db-gpt==0.4.1) (1.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->db-gpt==0.4.1) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->db-gpt==0.4.1) (0.1.99)
# Requirement already satisfied: PyJWT in /usr/lib/python3/dist-packages (from zhipuai->db-gpt==0.4.1) (2.3.0)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.10/dist-packages (from zhipuai->db-gpt==0.4.1) (0.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain>=0.0.286->db-gpt==0.4.1) (1.1.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain>=0.0.286->db-gpt==0.4.1) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain>=0.0.286->db-gpt==0.4.1) (0.9.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->GitPython->db-gpt==0.4.1) (5.0.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate>=0.20.3->db-gpt==0.4.1) (2023.6.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain>=0.0.286->db-gpt==0.4.1) (2.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->db-gpt==0.4.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->db-gpt==0.4.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->db-gpt==0.4.1) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->db-gpt==0.4.1) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->db-gpt==0.4.1) (3.1.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.10->db-gpt==0.4.1) (23.5.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb==0.4.10->db-gpt==0.4.1) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb==0.4.10->db-gpt==0.4.1) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb==0.4.10->db-gpt==0.4.1) (2.2.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb==0.4.10->db-gpt==0.4.1) (2.0.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.0.0->fschat->db-gpt==0.4.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.0.0->fschat->db-gpt==0.4.1) (2.16.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy==3.5.3->db-gpt==0.4.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy==3.5.3->db-gpt==0.4.1) (0.1.3)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.10->db-gpt==0.4.1) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.10->db-gpt==0.4.1) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.10->db-gpt==0.4.1) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.10->db-gpt==0.4.1) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.10->db-gpt==0.4.1) (12.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->db-gpt==0.4.1) (2.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy==3.5.3->db-gpt==0.4.1) (2.1.3)
# Requirement already satisfied: wavedrom in /usr/local/lib/python3.10/dist-packages (from markdown2[all]->fschat->db-gpt==0.4.1) (2.0.3.post3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers->db-gpt==0.4.1) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers->db-gpt==0.4.1) (3.2.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.1->db-gpt==0.4.1) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.0.0->fschat->db-gpt==0.4.1) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain>=0.0.286->db-gpt==0.4.1) (1.0.0)
# Requirement already satisfied: svgwrite in /usr/local/lib/python3.10/dist-packages (from wavedrom->markdown2[all]->fschat->db-gpt==0.4.1) (1.4.3)
# Installing collected packages: db-gpt
#   Running setup.py develop for db-gpt
# Successfully installed db-gpt-0.4.1

# %%
# !apt-get install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 6 not upgraded.

# %%
# !pip install -e ".[openai]"
# Out:
# Obtaining file:///content/drive/MyDrive/intern/llm_chatgpt_study/DB/DB-GPT
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: aiohttp==3.8.4 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (3.8.4)
# Requirement already satisfied: chardet==5.1.0 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (5.1.0)
# Requirement already satisfied: importlib-resources==5.12.0 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (5.12.0)
# Requirement already satisfied: psutil==5.9.4 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (5.9.4)
# Requirement already satisfied: python-dotenv==1.0.0 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (1.0.0)
# Requirement already satisfied: colorama==0.4.6 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.4.6)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (3.9.0)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (5.3.2)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (1.2.4)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.5.1)
# Requirement already satisfied: fschat in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.2.32)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (15.0.1)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.25.1)
# Requirement already satisfied: sqlparse==0.4.4 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.4.4)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.12.2)
# Requirement already satisfied: pandas==2.0.3 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (2.0.3)
# Requirement already satisfied: auto-gpt-plugin-template in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.0.3)
# Requirement already satisfied: gTTS==2.3.1 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (2.3.1)
# Requirement already satisfied: langchain>=0.0.286 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.0.335)
# Requirement already satisfied: SQLAlchemy==2.0.22 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (2.0.22)
# Requirement already satisfied: fastapi==0.98.0 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.98.0)
# Requirement already satisfied: pymysql in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (1.1.0)
# Requirement already satisfied: duckdb==0.8.1 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.8.1)
# Requirement already satisfied: duckdb-engine in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.9.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (4.19.2)
# Requirement already satisfied: transformers>=4.31.0 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (4.33.3)
# Requirement already satisfied: alembic==1.12.0 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (1.12.0)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (3.1.2)
# Requirement already satisfied: spacy==3.5.3 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (3.5.3)
# Requirement already satisfied: chromadb==0.4.10 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.4.10)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (3.5.1)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.0.1)
# Requirement already satisfied: python-pptx in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.6.23)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (1.1.0)
# Requirement already satisfied: pypdf in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (3.17.0)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.10/dist-packages (from db-gpt==0.4.1) (0.0.6)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.4->db-gpt==0.4.1) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.4->db-gpt==0.4.1) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.4->db-gpt==0.4.1) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.4->db-gpt==0.4.1) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.4->db-gpt==0.4.1) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.4->db-gpt==0.4.1) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp==3.8.4->db-gpt==0.4.1) (1.3.1)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic==1.12.0->db-gpt==0.4.1) (1.3.0)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic==1.12.0->db-gpt==0.4.1) (4.5.0)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (2.31.0)
# Requirement already satisfied: pydantic<2.0,>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (1.10.13)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (0.7.3)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (0.24.0.post1)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (3.0.2)
# Requirement already satisfied: pulsar-client>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (3.3.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (1.16.2)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (0.13.3)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (7.4.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (4.0.1)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb==0.4.10->db-gpt==0.4.1) (1.23.5)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from fastapi==0.98.0->db-gpt==0.4.1) (0.27.0)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.10/dist-packages (from gTTS==2.3.1->db-gpt==0.4.1) (8.1.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3->db-gpt==0.4.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3->db-gpt==0.4.1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.0.3->db-gpt==0.4.1) (2023.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (2.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (6.4.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.3->db-gpt==0.4.1) (3.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy==2.0.22->db-gpt==0.4.1) (3.0.1)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.286->db-gpt==0.4.1) (6.0.1)
# Requirement already satisfied: anyio<4.0 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.286->db-gpt==0.4.1) (3.7.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.286->db-gpt==0.4.1) (0.6.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.286->db-gpt==0.4.1) (1.33)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.63 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.286->db-gpt==0.4.1) (0.0.64)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain>=0.0.286->db-gpt==0.4.1) (8.2.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->db-gpt==0.4.1) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->db-gpt==0.4.1) (0.19.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->db-gpt==0.4.1) (2023.6.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.31.0->db-gpt==0.4.1) (0.4.0)
# Requirement already satisfied: abstract-singleton in /usr/local/lib/python3.10/dist-packages (from auto-gpt-plugin-template->db-gpt==0.4.1) (1.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->db-gpt==0.4.1) (4.11.2)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->db-gpt==0.4.1) (10.0)
# Requirement already satisfied: markdown2[all] in /usr/local/lib/python3.10/dist-packages (from fschat->db-gpt==0.4.1) (2.4.10)
# Requirement already satisfied: nh3 in /usr/local/lib/python3.10/dist-packages (from fschat->db-gpt==0.4.1) (0.2.14)
# Requirement already satisfied: prompt-toolkit>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from fschat->db-gpt==0.4.1) (3.0.39)
# Requirement already satisfied: rich>=10.0.0 in /usr/local/lib/python3.10/dist-packages (from fschat->db-gpt==0.4.1) (13.6.0)
# Requirement already satisfied: shortuuid in /usr/local/lib/python3.10/dist-packages (from fschat->db-gpt==0.4.1) (1.0.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->db-gpt==0.4.1) (2023.7.22)
# Requirement already satisfied: httpcore in /usr/local/lib/python3.10/dist-packages (from httpx->db-gpt==0.4.1) (1.0.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->db-gpt==0.4.1) (3.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->db-gpt==0.4.1) (1.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->db-gpt==0.4.1) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->db-gpt==0.4.1) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->db-gpt==0.4.1) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai->db-gpt==0.4.1) (1.7.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->db-gpt==0.4.1) (1.1.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->db-gpt==0.4.1) (0.2.9)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx->db-gpt==0.4.1) (4.9.3)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from python-pptx->db-gpt==0.4.1) (9.4.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from python-pptx->db-gpt==0.4.1) (3.1.9)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn->db-gpt==0.4.1) (3.7.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0->langchain>=0.0.286->db-gpt==0.4.1) (1.1.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain>=0.0.286->db-gpt==0.4.1) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain>=0.0.286->db-gpt==0.4.1) (0.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers>=4.31.0->db-gpt==0.4.1) (2023.6.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain>=0.0.286->db-gpt==0.4.1) (2.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->db-gpt==0.4.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->db-gpt==0.4.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->db-gpt==0.4.1) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->db-gpt==0.4.1) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn->db-gpt==0.4.1) (3.1.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.10->db-gpt==0.4.1) (23.5.26)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.10->db-gpt==0.4.1) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb==0.4.10->db-gpt==0.4.1) (1.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb==0.4.10->db-gpt==0.4.1) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb==0.4.10->db-gpt==0.4.1) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb==0.4.10->db-gpt==0.4.1) (2.2.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb==0.4.10->db-gpt==0.4.1) (2.0.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.0.0->fschat->db-gpt==0.4.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.0.0->fschat->db-gpt==0.4.1) (2.16.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy==3.5.3->db-gpt==0.4.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy==3.5.3->db-gpt==0.4.1) (0.1.3)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.10->db-gpt==0.4.1) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.10->db-gpt==0.4.1) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.10->db-gpt==0.4.1) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.10->db-gpt==0.4.1) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb==0.4.10->db-gpt==0.4.1) (12.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->db-gpt==0.4.1) (2.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy==3.5.3->db-gpt==0.4.1) (2.1.3)
# Requirement already satisfied: wavedrom in /usr/local/lib/python3.10/dist-packages (from markdown2[all]->fschat->db-gpt==0.4.1) (2.0.3.post3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.0.0->fschat->db-gpt==0.4.1) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain>=0.0.286->db-gpt==0.4.1) (1.0.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb==0.4.10->db-gpt==0.4.1) (1.3.0)
# Requirement already satisfied: svgwrite in /usr/local/lib/python3.10/dist-packages (from wavedrom->markdown2[all]->fschat->db-gpt==0.4.1) (1.4.3)
# Installing collected packages: db-gpt
#   Attempting uninstall: db-gpt
#     Found existing installation: db-gpt 0.4.1
#     Uninstalling db-gpt-0.4.1:
#       Successfully uninstalled db-gpt-0.4.1
#   Running setup.py develop for db-gpt
# Successfully installed db-gpt-0.4.1

# %%
pwd
# Out:
# '/content/drive/MyDrive/intern/llm_chatgpt_study/DB/DB-GPT/models'

# %%
# !mkdir models

# %%
cd models
# Out:
# /content/drive/MyDrive/intern/llm_chatgpt_study/DB/DB-GPT/models

# %%
# !git clone https://huggingface.co/GanymedeNil/text2vec-large-chinese
# Out:
# fatal: destination path 'text2vec-large-chinese' already exists and is not an empty directory.

# %%
cd ../
# Out:
# /content/drive/MyDrive/intern/llm_chatgpt_study/DB/DB-GPT

# %% [markdown]
# - .env파일에서 다음을 입력해야 함.
# ```
# LLM_MODEL=chatgpt_proxyllm
# PROXY_API_KEY="" #api_key를 입력
# PROXY_SERVER_URL=https://api.openai.com/v1/chat/completions
# ```

# %%
# !python pilot/server/dbgpt_server.py # 실행은 되지만 브라우저에서 접속이 안된다.

# %%
# !uvicorn pilot.server.dbgpt_server:app --host 0.0.0.0 --port 3000
# Out:
# INFO:     Started server process [24233]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:3000 (Press CTRL+C to quit)
# INFO:     Shutting down
# INFO:     Finished server process [24233]
# ERROR:    Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/starlette/routing.py", line 686, in lifespan
#     await receive()
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#   File "/usr/lib/python3.10/asyncio/queues.py", line 159, in get
#     await getter
# asyncio.exceptions.CancelledError
